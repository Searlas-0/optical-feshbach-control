# %%
from typing import NamedTuple

class Params(NamedTuple):
    a_bg: float
    gamma: float
    Gamma_max: float
    dt: float

params = Params(
    a_bg=1.0,
    gamma=1.0,
    Gamma_max=10.0,
    dt=1e-3,
)
