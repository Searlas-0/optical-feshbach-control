# %%
from config import Config
from run_tests import Test

#Example test run
config_1 = Config()
test_1 = Test(config_1)
# Out:
# WARNING:2026-07-25 14:24:15,001:jax._src.xla_bridge:794: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# Parameters used:
#   a_bg: 1.0
#   gamma: 1.0
#   Gamma_max: 50.0
#   detuning_max: 50.0
#   t_interval: 1.0
#   N: 100
#   dt: 0.01
#   loss: True
#   u_isbound: True
#   v_isbound: True
#   u_max: 50.0
#   v_max: 50.0
#   a_isbound: True
#   a_max: 50.0
#   a_min: 1e-05
#   seed: 0
#   sim_num: 13
#   num_steps: 1000
#   learning_rate: 0.01
#   beta1: 0.9
#   beta2: 0.999
#   eps: 1e-08
#   u_smooth: 0.0001
#   v_smooth: 0.0001
#   a_smooth: 0.0001
#   use_jit: True
#   use_x64: True
#   init_scale: 0.1
#   plot_columns: 3
# 1/13 : 0.803 s
# 2/13 : 0.559 s
# 3/13 : 0.569 s
# 4/13 : 0.571 s
# 5/13 : 0.586 s
# 6/13 : 0.605 s
# 7/13 : 0.574 s
# 8/13 : 0.577 s
# 9/13 : 0.569 s
# 10/13 : 0.587 s
# 11/13 : 0.579 s
# 12/13 : 0.578 s
# 13/13 : 0.647 s
# Average runtime per optimisation: 0.600 s

# %%
config_2 = config_1.update(num_steps = 10000)
test_2 = Test(config_2)
# Out:
# Parameters used:
#   a_bg: 1.0
#   gamma: 1.0
#   Gamma_max: 50.0
#   detuning_max: 50.0
#   t_interval: 1.0
#   N: 100
#   dt: 0.01
#   loss: True
#   u_isbound: True
#   v_isbound: True
#   u_max: 50.0
#   v_max: 50.0
#   a_isbound: True
#   a_max: 50.0
#   a_min: 1e-05
#   seed: 0
#   sim_num: 13
#   num_steps: 10000
#   learning_rate: 0.01
#   beta1: 0.9
#   beta2: 0.999
#   eps: 1e-08
#   u_smooth: 0.0001
#   v_smooth: 0.0001
#   a_smooth: 0.0001
#   use_jit: True
#   use_x64: True
#   init_scale: 0.1
#   plot_columns: 3
# 1/13 : 3.364 s
# 2/13 : 3.427 s
# 3/13 : 3.337 s
# 4/13 : 3.351 s
# 5/13 : 3.360 s
# 6/13 : 3.394 s
# 7/13 : 3.331 s
# 8/13 : 3.453 s
# 9/13 : 3.375 s
# 10/13 : 3.411 s
# 11/13 : 3.474 s
# 12/13 : 3.351 s
# 13/13 : 3.361 s
# Average runtime per optimisation: 3.384 s

# %%
config_3 = config_2.update(N = 1000)
test_2 = Test(config_2)
# Out:
# Parameters used:
#   a_bg: 1.0
#   gamma: 1.0
#   Gamma_max: 50.0
#   detuning_max: 50.0
#   t_interval: 1.0
#   N: 100
#   dt: 0.01
#   loss: True
#   u_isbound: True
#   v_isbound: True
#   u_max: 50.0
#   v_max: 50.0
#   a_isbound: True
#   a_max: 50.0
#   a_min: 1e-05
#   seed: 0
#   sim_num: 13
#   num_steps: 10000
#   learning_rate: 0.01
#   beta1: 0.9
#   beta2: 0.999
#   eps: 1e-08
#   u_smooth: 0.0001
#   v_smooth: 0.0001
#   a_smooth: 0.0001
#   use_jit: True
#   use_x64: True
#   init_scale: 0.1
#   plot_columns: 3
# 1/13 : 3.399 s
# 2/13 : 3.373 s
# 3/13 : 3.429 s
# 4/13 : 3.352 s
# 5/13 : 3.302 s
# 6/13 : 3.410 s
# 7/13 : 3.312 s
# 8/13 : 3.336 s
# 9/13 : 3.328 s
# 10/13 : 3.358 s
# 11/13 : 3.267 s
# 12/13 : 3.333 s
# 13/13 : 3.320 s
# Average runtime per optimisation: 3.348 s
